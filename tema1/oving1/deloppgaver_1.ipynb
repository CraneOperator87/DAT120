# %%
# Deloppgave d. forklar koden.
masse = input("Skriv inn massen til objektet: ") # User-input for masse
masse_tall = float(masse)                        # konverterer input til flaot
fart = input("Skriv inn farten til objektet: ")  # user input for fart
fart_tall = float(fart)                          # konverterer input til float
resultat = 0.5*masse_tall*fart_tall*fart_tall    # beregner alt sammen
print(resultat)                                  # Til slutt skriver ut svaret.

"""
Koden tar inn en masse og en fart. det ser vi blir gjort i linje 1 og 3. Tallet vi oppgir blir konvertert til float.
Deretter blir tallene multiplisert med o.5 og da får vi resultatet til objektets kinetiske energi i siste linje.
"""
# Out:
# 1000.0

# %% [markdown]
# Deloppgave e: Basis Python script: Skriv et Python script som konverterer avstander fra kilometer til
# nautiske mil. Brukeren skal skrive inn avstanden i kilometer. Programmet skal skrive ut
# avstanden i nautiske mil. En nautisk mil er 1,852 kilometer.

# %%
# Deloppgave e
kilometer = input("Skriv inn antall kilometer: ")
kilometer_fl = float(kilometer)

nautisk_mil = kilometer_fl / float(1.852) 
print(f"du får {nautisk_mil:.2f} nautiske mil fra {kilometer} kilometer")

# %% [markdown]
# Deloppgave f: Basis Python script: Man oppgir vanligvis størrelsen til en TV eller dataskjerm som antall
# tommer langs diagonalen. For å finne ut om det er plass til TV-en der du tenker å ha den
# trenger du ofte å vite bredden og høyden til TV-en. Skriv et Python-script som regner ut
# bredde og høyde til en skjerm basert på lengden til diagonalen. Brukeren skal oppgi denne
# diagonale lengden. Anta at skjermen er på 16:9 format (forholdet mellom bredde og høyde
# er 16:9, en skjerm som er 16 brei er 9 høy). Scriptet skal skrive ut lengden og bredden til
# skjermen. Du kan skrive ut lengde og bredde i samme enhet som brukeren oppgir diagonalen
# i (typisk tommer).

# %%
# Deloppgave F
user_input = float(input("Skriv antall tommer til tv, eller skjerm: "))

aspect_h, aspect_b = 9, 16
scale = (aspect_b ** 2 + aspect_h ** 2)**0.5

bredde = user_input * aspect_b / scale
høyde = user_input * aspect_h /scale

print(f"Bredde til tven med {user_input} tommer : {bredde:.1f}' -> {bredde * 2.54:.1f} cm")
print(f"Høyden til tven med {user_input} tommer : {høyde:.1f}' -> {høyde * 2.54:.1f} cm")
# Out:
# Bredde til tven med 24.0 tommer : 20.9' -> 53.1 cm
# Høyden til tven med 24.0 tommer : 11.8' -> 29.9 cm
